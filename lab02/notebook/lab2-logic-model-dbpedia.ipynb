# %% [markdown]
# # Laboratório 2
# ### Gabriel Costa Kinder - 234720

# %%
import io
import requests
import json

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"

concept = "Tent of Miracles (novel)"
format = "jsod"

concept = concept.replace(" ", "_")

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
js = data.json()
print(json.dumps(js, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/French_New_Wave"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/WrittenWork"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#             "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#             "http://dbpedia.org/property/pubDate": "1969",
#             "http://dbpedia.org/property/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#             "http://dbpedia.org/property/englishPubDate": "1971",
#             "http://dbpedia.org/ontology/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/property/name": "Tent of Miracles",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/ontology/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "5253",
#             "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "623351",
#             "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/caption": "First edition",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
author = js["d"]["results"][0]["http://dbpedia.org/ontology/author"]["__deferred"]["uri"]
print("Autor de Tent of Miracles: " + author)
# Out:
# Autor de Tent of Miracles: http://dbpedia.org/resource/Jorge_Amado

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}&limit={limit}"

concept = "Aspirin"
match = "exact"
limit = "10"

concept = concept.replace(" ", "%20")

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)\
                  .replace("{limit}", limit)

data = requests.get(url)
json_mi = data.json()

uri_mesh = json_mi[0]["resource"]
bar = str.rindex(uri_mesh, "/")

url_template = "https://id.nlm.nih.gov/mesh/lookup/details?descriptor={code}"

code = uri_mesh[bar+1:]

url = url_template.replace("{code}", code)

data = requests.get(url)
json_mid = data.json()
print(json.dumps(json_mid['terms'], indent=3))
# Out:
# [
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003713",
#       "label": "Aspirin",
#       "preferred": true
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003714",
#       "label": "2-(Acetyloxy)benzoic Acid",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003712",
#       "label": "Acetylsalicylic Acid",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003721",
#       "label": "Acetysal",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003722",
#       "label": "Acylpyrin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003711",
#       "label": "Aloxiprimum",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003723",
#       "label": "Colfarit",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003715",
#       "label": "Dispril",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003719",
#       "label": "Easprin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003724",
#       "label": "Ecotrin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003725",
#       "label": "Endosprin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003726",
#       "label": "Magnecyl",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003727",
#       "label": "Micristin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003717",
#       "label": "Polopirin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003728",
#       "label": "Polopiryna",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003716",
#       "label": "Solprin",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003718",
#       "label": "Solupsan",
#       "preferred": false
#    },
#    {
#       "resource": "http://id.nlm.nih.gov/mesh/T003720",
#       "label": "Zorprin",
#       "preferred": false
#    }
# ]

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "Harvard University, North Harvard Street"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
harvard_ref = data.json()
print(json.dumps(harvard_ref, indent=3))
# Out:
# [
#    {
#       "place_id": 258370425,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "relation",
#       "osm_id": 2415825,
#       "boundingbox": [
#          "42.3595885",
#          "42.3838746",
#          "-71.1360651",
#          "-71.1104568"
#       ],
#       "lat": "42.36790855",
#       "lon": "-71.12678237443698",
#       "display_name": "Harvard University, North Harvard Street, Allston, Boston, Suffolk County, Massachusetts, 02134-1433, United States",
#       "class": "amenity",
#       "type": "university",
#       "importance": 1.2771907226536725,
#       "icon": "https://nominatim.openstreetmap.org/ui/mapicons//education_university.p.20.png"
#    }
# ]

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "relation" # types: node, way, or relation
id = str(harvard_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
harvard_relation = data.json()
print(json.dumps(harvard_relation, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (1898455 spike-08.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "relation",
#          "id": 2415825,
#          "timestamp": "2021-06-05T02:06:19Z",
#          "version": 38,
#          "changeset": 105865910,
#          "user": "enjawoke",
#          "uid": 6540180,
#          "members": [
#             {
#                "type": "way",
#                "ref": 37093980,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 303677235,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 947498343,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 36897597,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 37326407,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 37329478,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 263292513,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 292112512,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 29636269,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 29921382,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 29887931,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 29796159,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 323920749,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 338148445,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 324172839,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 324174302,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 338148444,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 338148446,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 37329431,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 345605349,
#                "role": "outer"
#             },
#             {
#                "type": "way",
#                "ref": 345605350,
#                "role": ""
#             }
#          ],
#          "tags": {
#             "amenity": "university",
#             "ele": "6",
#             "gnis:county_id": "017",
#             "gnis:created": "08/27/2002",
#             "gnis:feature_id": "618399",
#             "gnis:state_id": "25",
#             "name": "Harvard University",
#             "name:ar": "\u062c\u0627\u0645\u0639\u0629 \u0647\u0627\u0631\u0641\u0627\u0631\u062f",
#             "name:az": "Harvard Universiteti",
#             "name:ba": "\u0413\u0430\u0440\u0432\u0430\u0440\u0434 \u0443\u043d\u0438\u0432\u0435\u0440\u0441\u0438\u0442\u0435\u0442\u044b",
#             "name:be": "\u0413\u0430\u0440\u0432\u0430\u0440\u0434\u0441\u043a\u0456 \u045e\u043d\u0456\u0432\u0435\u0440\u0441\u0456\u0442\u044d\u0442",
#             "name:bg": "\u0425\u0430\u0440\u0432\u0430\u0440\u0434\u0441\u043a\u0438 \u0443\u043d\u0438\u0432\u0435\u0440\u0441\u0438\u0442\u0435\u0442",
#             "name:bn": "\u09b9\u09be\u09b0\u09cd\u09ad\u09be\u09b0\u09cd\u09a1 \u09ac\u09bf\u09b6\u09cd\u09ac\u09ac\u09bf\u09a6\u09cd\u09af\u09be\u09b2\u09af\u09bc",
#             "name:br": "Skol-veur Harvard",
#             "name:ca": "Universitat de Harvard",
#             "name:cs": "Harvardova univerzita",
#             "name:cv": "\u0425\u0430\u0440\u0432\u0103\u0440\u0442 \u0423\u043d\u0438\u0432\u0435\u0440\u0441\u0438\u0442\u0435\u0447\u0115",
#             "name:cy": "Prifysgol Harvard",
#             "name:da": "Harvard",
#             "name:el": "\u03a0\u03b1\u03bd\u03b5\u03c0\u03b9\u03c3\u03c4\u03ae\u03bc\u03b9\u03bf \u03a7\u03ac\u03c1\u03b2\u03b1\u03c1\u03bd\u03c4",
#             "name:eo": "Universitato Harvard",
#             "name:es": "Universidad de Harvard",
#             "name:et": "Harvardi \u00fclikool",
#             "name:eu": "Harvard Unibertsitatea",
#             "name:fa": "\u062f\u0627\u0646\u0634\u06af\u0627\u0647 \u0647\u0627\u0631\u0648\u0627\u0631\u062f",
#             "name:fi": "Harvardin yliopisto",
#             "name:fr": "Universit\u00e9 Harvard",
#             "name:ga": "Ollscoil Harvard",
#             "name:gd": "Oilthigh Harvard",
#             "name:gl": "Universidade Harvard",
#             "name:he": "\u05d0\u05d5\u05e0\u05d9\u05d1\u05e8\u05e1\u05d9\u05d8\u05ea \u05d4\u05e8\u05d5\u05d5\u05d0\u05e8\u05d3",
#             "name:hi": "\u0939\u093e\u0930\u094d\u0935\u0930\u094d\u0921 \u0935\u093f\u0936\u094d\u0935\u0935\u093f\u0926\u094d\u092f\u093e\u0932\u092f",
#             "name:hr": "Sveu\u010dili\u0161te Harvard",
#             "name:hu": "Harvard Egyetem",
#             "name:hy": "\u0540\u0561\u0580\u057e\u0561\u0580\u0564\u056b \u0570\u0561\u0574\u0561\u056c\u057d\u0561\u0580\u0561\u0576",
#             "name:id": "Universitas Harvard",
#             "name:is": "Harvard-h\u00e1sk\u00f3li",
#             "name:it": "Universit\u00e0 di Harvard",
#             "name:ja": "\u30cf\u30fc\u30d0\u30fc\u30c9\u5927\u5b66",
#             "name:jv": "Universitas Harvard",
#             "name:ka": "\u10f0\u10d0\u10e0\u10d5\u10d0\u10e0\u10d3\u10d8\u10e1 \u10e3\u10dc\u10d8\u10d5\u10d4\u10e0\u10e1\u10d8\u10e2\u10d4\u10e2\u10d8",
#             "name:kk": "\u0413\u0430\u0440\u0432\u0430\u0440\u0434 \u0443\u043d\u0438\u0432\u0435\u0440\u0441\u0438\u0442\u0435\u0442\u0456",
#             "name:kn": "\u0cb9\u0cbe\u0cb0\u0ccd\u0cb5\u0cb0\u0ccd\u0ca1\u0ccd \u0cb5\u0cbf\u0cb6\u0ccd\u0cb5\u0cb5\u0cbf\u0ca6\u0ccd\u0caf\u0cbe\u0ca8\u0cbf\u0cb2\u0caf",
#             "name:ko": "\ud558\ubc84\ub4dc \ub300\ud559\uad50",
#             "name:ku": "Zan\u00eengeha Harvard\u00ea",
#             "name:la": "Universitas Harvardiana",
#             "name:lb": "Harvard Universit\u00e9it",
#             "name:lt": "Harvardo universitetas",
#             "name:lv": "H\u0101rvarda universit\u0101te",
#             "name:mk": "\u0425\u0430\u0440\u0432\u0430\u0440\u0434",
#             "name:mr": "\u0939\u093e\u0930\u094d\u0935\u0930\u094d\u0921 \u0935\u093f\u0926\u094d\u092f\u093e\u092a\u0940\u0920",
#             "name:ms": "Universiti Harvard",
#             "name:my": "\u101f\u102c\u1038\u1017\u1010\u103a \u1010\u1000\u1039\u1000\u101e\u102d\u102f\u101c\u103a",
#             "name:nl": "Harvard-universiteit",
#             "name:oc": "Universitat de Harvard",
#             "name:pt": "Universidade Harvard",
#             "name:qu": "Harvard Yachay Suntur",
#             "name:ro": "Universitatea Harvard",
#             "name:ru": "\u0413\u0430\u0440\u0432\u0430\u0440\u0434\u0441\u043a\u0438\u0439 \u0443\u043d\u0438\u0432\u0435\u0440\u0441\u0438\u0442\u0435\u0442",
#             "name:sa": "\u0939\u093e\u0930\u094d\u0935\u0930\u094d\u0921\u094d \u0935\u093f\u0936\u094d\u0935\u0935\u093f\u0926\u094d\u092f\u093e\u0932\u092f\u0903",
#             "name:sl": "Univerza Harvard",
#             "name:sq": "Harvard",
#             "name:sr": "\u0423\u043d\u0438\u0432\u0435\u0440\u0437\u0438\u0442\u0435\u0442 \u0425\u0430\u0440\u0432\u0430\u0440\u0434",
#             "name:sw": "Chuo Kikuu cha Harvard",
#             "name:ta": "\u0bb9\u0bbe\u0bb0\u0bcd\u0bb5\u0bb0\u0bcd\u0b9f\u0bc1 \u0baa\u0bb2\u0bcd\u0b95\u0bb2\u0bc8\u0b95\u0bcd\u0b95\u0bb4\u0b95\u0bae\u0bcd",
#             "name:te": "\u0c39\u0c3e\u0c30\u0c4d\u0c35\u0c30\u0c4d\u0c21\u0c4d \u0c35\u0c3f\u0c36\u0c4d\u0c35\u0c35\u0c3f\u0c26\u0c4d\u0c2f\u0c3e\u0c32\u0c2f\u0c02",
#             "name:th": "\u0e21\u0e2b\u0e32\u0e27\u0e34\u0e17\u0e22\u0e32\u0e25\u0e31\u0e22\u0e2e\u0e32\u0e23\u0e4c\u0e27\u0e32\u0e23\u0e4c\u0e14",
#             "name:tr": "Harvard \u00dcniversitesi",
#             "name:tt": "Harvard universitet\u0131",
#             "name:ug": "\u062e\u0627\u0631\u06cb\u0627\u0631\u062f \u0626\u06c7\u0646\u0649\u06cb\u06d0\u0631\u0633\u0649\u062a\u06d0\u062a\u0649",
#             "name:uk": "\u0413\u0430\u0440\u0432\u0430\u0440\u0434\u0441\u044c\u043a\u0438\u0439 \u0443\u043d\u0456\u0432\u0435\u0440\u0441\u0438\u0442\u0435\u0442",
#             "name:ur": "\u062c\u0627\u0645\u0639\u06c1 \u06c1\u0627\u0631\u0648\u0631\u0688",
#             "name:vi": "\u0110\u1ea1i h\u1ecdc Harvard",
#             "name:yi": "\u05d4\u05d0\u05e8\u05d5\u05d5\u05d0\u05e8\u05d3 \u05d0\u05d5\u05e0\u05d9\u05d5\u05d5\u05e2\u05e8\u05e1\u05d9\u05d8\u05e2\u05d8",
#             "name:yo": "Yunif\u00e1s\u00edt\u00ec Harvard",
#             "name:zh": "\u54c8\u4f5b\u5927\u5b66",
#             "type": "multipolygon",
#             "wikidata": "Q13371",
#             "wikipedia": "en:Harvard University"
#          }
#       }
#    ]
# }

# %%
url_template = "http://dbpedia.org/data/{concept}.{format}"
concept = harvard_relation["elements"][0]["tags"]["wikipedia"].replace(" ", "_")\
                                                        .replace("en:", "")
format = "jsod"

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
museum_dbpedia = data.json()
print(json.dumps(museum_dbpedia, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Harvard_University"
#             },
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Longwood_Medical_and_Academic_Area"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://ta.dbpedia.org/resource/\u0b86\u0bb0\u0bcd\u0bb5\u0bb0\u0bcd\u0b9f\u0bc1_\u0baa\u0bb2\u0bcd\u0b95\u0bb2\u0bc8\u0b95\u0bcd\u0b95\u0bb4\u0b95\u0bae\u0bcd"
#                }
#             },
#             "http://dbpedia.org/property/wamoNu": "2",
#             "http://dbpedia.org/ontology/abstract": "La Universitat Harvard (en angl\u00e8s: Harvard University) \u00e9s una universitat privada situada a Cambridge, Massachusetts, als Estats Units d&#39;Am\u00e8rica, prop de la ciutat de Boston. \u00c9s la universitat m\u00e9s antiga de tot Nord-Am\u00e8rica, havent estat fundada com a New College el 8 de setembre de 1636. Tres anys m\u00e9s tard va ser rebatejada en honor a John Harvard, un dels seus principals mecenes. Juntament amb set altres universitats antigues del Nord-Est, Harvard \u00e9s membre de l&#39;Ivy League, una lliga atl\u00e8tica formada per institucions d&#39;educaci\u00f3 superior extremadament selectives i amb dotacions financeres multimilion\u00e0ries. En aquest sentit, Harvard destaca tant per ser la segona universitat m\u00e9s selectiva dels Estats Units, com per ser el centre educatiu amb una dotaci\u00f3 m\u00e9s gran del planeta, valorada en 41.900 milions de d\u00f2lars. Amb prop de 6.750 estudiants de pregrau i uns 13.000 de postgrau, Harvard \u00e9s una universitat de mida mitjana amb un campus hist\u00f2ric a la riba nord del riu Charles. Centrat al voltant de l&#39;\u00e0rea oberta coneguda com a Harvard Yard, hi destaquen edificis de l&#39;\u00e8poca colonial com el Massachusetts Hall i la Capella Holden. La Biblioteca Widener, edifici de principis del segle XX, \u00e9s el centre del sistema bibliotecari de Harvard, el m\u00e9s antic dels Estats Units i la col\u00b7lecci\u00f3 bibliotec\u00e0ria privada m\u00e9s gran del m\u00f3n. En la seva llarga hist\u00f2ria, Harvard ha destacat com un dels centres d&#39;investigaci\u00f3 m\u00e9s importants del planeta, alhora que s&#39;ha consolidat en la cultura popular com una de les universitats m\u00e9s ic\u00f2niques del m\u00f3n, amb centenars d&#39;ex-alumnes famosos que han desenvolupat carreres acad\u00e8miques, pol\u00edtiques i art\u00edstiques d&#39;\u00e8xit. Sol apar\u00e8ixer als r\u00e0nquings d&#39;universitats entre les dues primeres posicions als Estats Units i entre les cinc primeres del m\u00f3n, la qual cosa la fa una de les universitats m\u00e9s prestigioses globalment.",
#             "http://dbpedia.org/property/free": "The Harvard Crimson",
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://schema.org/CollegeOrUniversity"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#seeAlso": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Academic_Area"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:URL"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Universidade Harvard (em ingl\u00eas: Harvard University) \u00e9 uma universidade privada situada na cidade de Cambridge, estado de Massachusetts, nos Estados Unidos. \u00c9 um membro da Ivy League. Sua hist\u00f3ria, influ\u00eancia e riqueza tornam-na uma das mais prestigiadas universidades do mundo.",
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Harvard_University?oldid=1025358983&ns=0"
#                }
#             },
#             "http://dbpedia.org/property/b": "no",
#             "http://dbpedia.org/property/qsW": "3",
#             "http://dbpedia.org/ontology/type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Private_university"
#                }
#             },
#             "http://dbpedia.org/ontology/city": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Cambridge,_Massachusetts"
#                }
#             },
#             "http://dbpedia.org/property/type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Research_university"
#                }
#             },
#             "http://dbpedia.org/property/athletics": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/NCAA_Division_I"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageExternalLink": {
#                "__deferred": {
#                   "uri": "https://www.nytimes.com/2010/08/22/movies/22love.html"
#                }
#             },
#             "http://dbpedia.org/ontology/athletics": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/NCAA_Division_I"
#                }
#             },
#             "http://dbpedia.org/ontology/provost": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Alan_Garber"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Universitato Harvard",
#             "http://dbpedia.org/property/logoAlt": "Logotype of Harvard University",
#             "http://dbpedia.org/property/theWsj": "1",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#long": "-71.116943359375",
#             "http://dbpedia.org/property/country": "United States",
#             "http://dbpedia.org/property/academicAffiliations": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/National_Association_of_Independent_Colleges_and_Universities"
#                }
#             },
#             "http://dbpedia.org/ontology/state": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Massachusetts"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Harvard_University"
#                }
#             },
#             "http://dbpedia.org/property/q": "Harvard University",
#             "http://dbpedia.org/ontology/motto": "(Latin)",
#             "http://dbpedia.org/property/v": "no",
#             "http://dbpedia.org/property/state": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Massachusetts"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "18426501",
#             "http://dbpedia.org/property/academicStaff": "~2,400 faculty members",
#             "http://www.georss.org/georss/point": "42.37444444444444 -71.11694444444444",
#             "http://dbpedia.org/property/students": "20970",
#             "http://dbpedia.org/ontology/wikiPageLength": "84225",
#             "http://dbpedia.org/property/motto": "",
#             "http://dbpedia.org/property/thesW": "3",
#             "http://dbpedia.org/property/d": "q13371",
#             "http://dbpedia.org/property/nickname": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Harvard_Crimson"
#                }
#             },
#             "http://dbpedia.org/property/accreditation": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/New_England_Commission_of_Higher_Education"
#                }
#             },
#             "http://dbpedia.org/ontology/mascot": "John Harvard",
#             "http://dbpedia.org/property/arwuW": "1",
#             "http://xmlns.com/foaf/0.1/name": "Harvard University",
#             "http://www.w3.org/2004/02/skos/core#closeMatch": {
#                "__deferred": {
#                   "uri": "http://www.grid.ac/institutes/grid.38142.3c"
#                }
#             },
#             "http://dbpedia.org/property/latinName": "Universitas Harvardiana",
#             "http://dbpedia.org/ontology/formerName": "Harvard College",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Harvard_University"
#                }
#             },
#             "http://dbpedia.org/property/species": "no",
#             "http://dbpedia.org/property/city": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Cambridge,_Massachusetts"
#                }
#             },
#             "http://dbpedia.org/ontology/numberOfUndergraduateStudents": "6755",
#             "http://xmlns.com/foaf/0.1/depiction": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Harvard_University_logo.PNG"
#                }
#             },
#             "http://dbpedia.org/property/undergrad": "6755",
#             "http://dbpedia.org/property/forbes": "1",
#             "http://schema.org/sameAs": {
#                "__deferred": {
#                   "uri": "http://viaf.org/viaf/128987800"
#                }
#             },
#             "http://www.w3.org/2003/01/geo/wgs84_pos#geometry": "POINT(-71.116943359375 42.374443054199)",
#             "http://dbpedia.org/property/s": "Portal:Harvard University",
#             "http://dbpedia.org/property/formerNames": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Harvard_College"
#                }
#             },
#             "http://dbpedia.org/property/n": "no",
#             "http://dbpedia.org/property/language": "Mostly English",
#             "http://dbpedia.org/property/colors": "Crimson",
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "1025358983",
#             "http://dbpedia.org/ontology/numberOfStudents": "20970",
#             "http://dbpedia.org/property/campus": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Urban_area"
#                }
#             },
#             "http://www.w3.org/2003/01/geo/wgs84_pos#lat": "42.37444305419922",
#             "http://dbpedia.org/ontology/president": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Lawrence_Bacow"
#                }
#             },
#             "http://dbpedia.org/property/arwuNu": "1",
#             "http://dbpedia.org/property/wordnet_type": {
#                "__deferred": {
#                   "uri": "http://www.w3.org/2006/03/wn/wn20/instances/synset-university-noun-2"
#                }
#             },
#             "http://dbpedia.org/property/logo": "File:Harvard University logo.svg",
#             "http://dbpedia.org/property/usnwrW": "1",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/University"
#                }
#             },
#             "http://dbpedia.org/property/voy": "no",
#             "http://dbpedia.org/property/usnwrNu": "2",
#             "http://dbpedia.org/ontology/campus": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Urban_area"
#                }
#             },
#             "http://dbpedia.org/ontology/thumbnail": {
#                "__deferred": {
#                   "uri": "http://commons.wikimedia.org/wiki/Special:FilePath/Harvard_University_logo.PNG?width=300"
#                }
#             },
#             "http://dbpedia.org/property/mascot": "John Harvard",
#             "http://dbpedia.org/property/imageUpright": "0.7",
#             "http://dbpedia.org/ontology/endowment": "4.19E10",
#             "http://dbpedia.org/ontology/officialSchoolColour": "Crimson",
#             "http://dbpedia.org/property/president": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Lawrence_Bacow"
#                }
#             },
#             "http://dbpedia.org/property/commons": "Category:Harvard University",
#             "http://dbpedia.org/property/caption": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Heraldry_of_Harvard_University"
#                }
#             },
#             "http://dbpedia.org/property/provost": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Alan_Garber"
#                }
#             },
#             "http://dbpedia.org/ontology/numberOfPostgraduateStudents": "14215",
#             "http://dbpedia.org/property/wikt": "no",
#             "http://dbpedia.org/property/mottoeng": "Truth",
#             "http://dbpedia.org/property/postgrad": "14215",
#             "http://dbpedia.org/property/freeLabel": "Newspaper",
#             "http://dbpedia.org/property/endowment": "4.19E10",
#             "http://dbpedia.org/property/founder": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Massachusetts_General_Court"
#                }
#             },
#             "http://dbpedia.org/property/name": "Harvard University",
#             "http://xmlns.com/foaf/0.1/nick": "Harvard Crimson",
#             "http://www.w3.org/2004/02/skos/core#exactMatch": {
#                "__deferred": {
#                   "uri": "http://globalwordnet.org/ili/i54668"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }
