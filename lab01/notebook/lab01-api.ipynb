# %% [markdown]
# # Lab 1 - API de Acesso a Dados

# %% [markdown]
# # Tarefa 1
#
# Das fontes de dados disponíveis, tente encontrar fontes com formatos diferentes e importá-las via Python. Busque pelo menos dois formatos.

# %%
import pandas as pd
covid_data = pd.read_csv("https://covid.ourworldindata.org/data/owid-covid-data.csv")
print(covid_data)
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1           AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 111304      ZWE    Africa     Zimbabwe  2021-08-18     121498.0      452.0
# 111305      ZWE    Africa     Zimbabwe  2021-08-19     121902.0      404.0
# 111306      ZWE    Africa     Zimbabwe  2021-08-20     121902.0        0.0
# 111307      ZWE    Africa     Zimbabwe  2021-08-21     122487.0      585.0
# 111308      ZWE    Africa     Zimbabwe  2021-08-22     122652.0      165.0
#
# ...

# %%
import io
import requests
import json
data = requests.get("http://i3geo.saude.gov.br/i3geo/ogc.php?service=WFS&version=1.0.0&request=GetFeature&typeName=ubs_funcionamento&outputFormat=JSON")
js = data.json()
print(js["features"][:10])
# Out:
# [{'type': 'Feature', 'properties': [{'gid': '149'}, {'co_cnes': '2583216'}, {'lat': '-25.682977417434'}, {'long': '-53.8001786950115'}, {'no_fantasia': 'POSTO DE SAUDE SAO LUIZ CAPANEMA'}, {'no_logradouro': 'LINHA SAO LUIZ'}, {'nu_endereco': 'S/N'}, {'no_bairro': 'SAO LUIZ'}, {'nu_telefone': '(46)999765464'}, {'co_cep': '85760000'}, {'uf': 'PR'}, {'cidade': 'Capanema'}, {'ano_ubs_det': '2016'}, {'mes_ubs_det': '5'}], 'geometry': {'type': 'Point', 'coordinates': [-53.800178695012, -25.682977417434]}}, {'type': 'Feature', 'properties': [{'gid': '80'}, {'co_cnes': '2241587'}, {'lat': '-30.0006687641135'}, {'long': '-53.4959721565231'}, {'no_fantasia': 'ESF CENTRO'}, {'no_logradouro': 'RUA VEREADOR ADELINO CARDOSO'}, {'nu_endereco': '150'}, {'no_bairro': 'CENTRO'}, {'nu_telefone': '(55) 3236.1208'}, {'co_cep': '97210000'}, {'uf': 'RS'}, {'cidade': 'Formigueiro'}, {'ano_ubs_det': '2016'}, {'mes_ubs_det': '5'}], 'geometry': {'type': 'Point', 'coordinates': [-53.495972156523, -30.0006687641
# ...

# %% [markdown]
# # Tarefa 2
#
# ## Engenharia reversa
#
# Monte um diagramas que representem modelos dos dados que você terá acesso e como pretende associá-los. Coloque abaixo uma imagem do diagrama.

# %% [markdown]
# ![Diagrama-ER-Casos_de_COVID.png](attachment:Diagrama-ER-Casos_de_COVID.png)
